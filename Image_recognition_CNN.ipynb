# %% [markdown]
# <a href="https://colab.research.google.com/github/pilafniev/Active_Countour/blob/master/Image_recognition_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## CNN
#
# CNN to categorize a set of 10,000 test images into 10 categories.
#
# <br>**Features**
# * I was able to achieve an accuracy of 81% at a reasonable runtime. <br>
# * I looked into and incorporated model checkpoint to only save epocs that improve as well as dropout.
# * I further tweaked the architecture by decreasing the amount of convolutional filters per layer and concatenated pairs of 2 layers before calling max pooling.
# * I also played around with different droput values and chose those which gave me best performance.
#
# <br>**References**<br>
# * Professor Yuan-Fang Wang class notes.
# * Margaret Maynard-Reid tutorial on CNN with keras.

# %% [markdown]
# ## Download data

# %%
# !pip install -q -U tensorflow>=1.8.0
import tensorflow as tf
import keras

import numpy as np
import matplotlib.pyplot as plt

# Load the train data and test data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

print("x_train shape:", x_train.shape, "y_train shape:", y_train.shape)
# Out:
# x_train shape: (50000, 32, 32, 3) y_train shape: (50000, 1)

# %% [markdown]
# ## Visualize the data

# %%
# Print training set shape
print("x_train shape:", x_train.shape, "y_train shape:", y_train.shape)

# Print the number of training and test datasets
print(x_train.shape[0], 'train set')
print(x_test.shape[0], 'test set')

# Define the text labels
cifar10_labels = ["airplane",  # index 0
                        "auto",      # index 1
                        "bird",     # index 2 
                        "cat",        # index 3 
                        "deer",         # index 4
                        "dog",       # index 5
                        "frog",        # index 6 
                        "horse",      # index 7 
                        "ship",          # index 8 
                        "truck"]   # index 9

# Image index, you can pick any number between 0 and 59,999
img_index = 5
# y_train contains the lables, ranging from 0 to 9
label_index = y_train[img_index]
label_index = label_index[0]
print(type(label_index))
# Print the label, for example 2 Pullover
print ("y = " + str(label_index) + " " +(cifar10_labels[label_index]))
# # Show one of the images from the training dataset
plt.imshow(x_train[img_index])
# Out:
# x_train shape: (50000, 32, 32, 3) y_train shape: (50000, 1)
# 50000 train set
# 10000 test set
# <class 'numpy.uint8'>
# y = 1 auto

# %% [markdown]
# ## Data normalization
# Normalize the data dimensions so that they are of approximately the same scale.

# %%
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# %%
print("Number of train data - " + str(len(x_train)))
print("Number of test data - " + str(len(x_test)))
# Out:
# Number of train data - 50000
# Number of test data - 10000

# %% [markdown]
# ## Debug Step

# %%
# One-hot encode the labels
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# Print training set shape
print("x_train shape:", x_train.shape, "y_train shape:", y_train.shape)

# Print the number of training and test datasets
print(x_train.shape[0], 'train set')
print(x_test.shape[0], 'validation set')
print(x_test.shape[0], 'test set')
# Out:
# x_train shape: (50000, 32, 32, 3) y_train shape: (50000, 10)
# 50000 train set
# 10000 validation set
# 10000 test set

# %% [markdown]
# ## Create network topology

# %%
model = tf.keras.Sequential()

# Must define the input shape in the first layer of the neural network
model.add(tf.keras.layers.Conv2D(filters=16, kernel_size=3, padding='same', activation='relu', input_shape=(32,32,3)))
model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=2))

model.add(tf.keras.layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
model.add(tf.keras.layers.Conv2D(filters=128, kernel_size=3, padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model.add(tf.keras.layers.Dropout(0.2))

model.add(tf.keras.layers.Conv2D(filters=128, kernel_size=3, padding='same', activation='relu'))
model.add(tf.keras.layers.Conv2D(filters=256, kernel_size=3, padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=2))
# model.add(tf.keras.layers.Dropout(0.6))

model.add(tf.keras.layers.Flatten())
# model.add(tf.keras.layers.Dense(256, activation='relu'))
model.add(tf.keras.layers.Dropout(0.6))
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# Take a look at the model summary
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 32, 32, 16)        448
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 32, 32, 32)        4640
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 8, 8, 128)         147584
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 581,162
# Trainable params: 581,162
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compile the model

# %%
model.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])

# %% [markdown]
# ## Train the model

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, Callback
import time

class TimeHistory(Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, epoch, logs={}):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, epoch, logs={}):
        self.times.append(time.time() - self.epoch_time_start)
        
time_callback = TimeHistory()

checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose = 1, save_best_only=True)
history = model.fit(x_train,
         y_train,
         batch_size=64,
         epochs=10,
         validation_data=(x_test, y_test),
         callbacks=[checkpointer, time_callback])
model.save('model.cifar10.h5')

#Plot Epoch Time
times = time_callback.times
plt.plot(time_callback.times)
plt.title('Epoch Times')
plt.ylabel('Time(s)')
plt.xlabel('Epoch')
plt.show()
# Plot Accuracy Data
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train Accuracy', 'Test Accuracy'], loc='upper left')
plt.show()
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 49792/50000 [============================>.] - ETA: 0s - loss: 1.6110 - acc: 0.4029
# Epoch 00001: val_loss improved from inf to 1.19052, saving model to model.weights.best.hdf5
# 50000/50000 [==============================] - 9s 185us/sample - loss: 1.6094 - acc: 0.4035 - val_loss: 1.1905 - val_acc: 0.5707
# Epoch 2/10
# 49920/50000 [============================>.] - ETA: 0s - loss: 1.1126 - acc: 0.6015
# Epoch 00002: val_loss improved from 1.19052 to 0.97728, saving model to model.weights.best.hdf5
# 50000/50000 [==============================] - 9s 176us/sample - loss: 1.1124 - acc: 0.6015 - val_loss: 0.9773 - val_acc: 0.6546
# Epoch 3/10
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.9151 - acc: 0.6751
# Epoch 00003: val_loss improved from 0.97728 to 0.84957, saving model to model.weights.best.hdf5
# 50000/50000 [==============================] - 8s 169us/sample - loss: 0.9152 - acc: 0.6751 - val_loss: 0.8496 - val_acc: 0.7014
# Epoch 4/10
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.7993 - acc: 0.7181
# Epoch 00004: val_loss improved from 0.84957 to 0.78033, saving model to model.weights.best.hdf5
# 50000/50000 [==============================] - 8s 168us/sample - loss: 0.7990 - acc: 0.7182 - val_loss: 0.7803 - val_acc: 0.7273
# Epoch 5/10
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.7140 - acc: 0.7491
# Epoch 00005: val_loss improved from 0.78033 to 0.70377, saving model to model.weights.best.hdf5
# 50000/50000 [==============================] - 8s 166us/sample - loss: 0.7137 - acc: 0.7492 - val_loss: 0.7038 - val_acc: 0.7574
# Epoch 6/10
# 49728/50000 [============================>.] - ETA: 0s - loss: 0.6501 - acc: 0.7722
# Epoch 00006: val_loss improved from 0.70377 to 0.69122, saving model to model.weights.best.hdf5
# 50000/50000 [==============================] - 9s 176us/sample - loss: 0.6501 - acc: 0.7723 - val_loss: 0.6912 - val_acc: 0.7562
# Epoch 7/10
# 49728/50000 [============================>.] - ETA: 0s - loss: 0.5972 - acc: 0.7889
# Epoch 00007: val_loss improved from 0.69122 to 0.63443, saving model to model.weights.best.hdf5
# 50000/50000 [==============================] - 9s 179us/sample - loss: 0.5971 - acc: 0.7889 - val_loss: 0.6344 - val_acc: 0.7829
# Epoch 8/10
# 49856/50000 [============================>.] - ETA: 0s - loss: 0.5595 - acc: 0.8040
# Epoch 00008: val_loss improved from 0.63443 to 0.60929, saving model to model.weights.best.hdf5
# 50000/50000 [==============================] - 9s 173us/sample - loss: 0.5594 - acc: 0.8039 - val_loss: 0.6093 - val_acc: 0.7877
# Epoch 9/10
# 49728/50000 [============================>.] - ETA: 0s - loss: 0.5249 - acc: 0.8148
# Epoch 00009: val_loss did not improve from 0.60929
# 50000/50000 [==============================] - 9s 170us/sample - loss: 0.5252 - acc: 0.8147 - val_loss: 0.6240 - val_acc: 0.7857
# Epoch 10/10
# 49728/50000 [============================>.] - ETA: 0s - loss: 0.4931 - acc: 0.8268
# Epoch 00010: val_loss did not improve from 0.60929
# 50000/50000 [==============================] - 9s 182us/sample - loss: 0.4936 - acc: 0.8267 - val_loss: 0.6153 - val_acc: 0.7966

# %% [markdown]
# ## Load Model

# %%
# Load entire model 
# model = load_model('model.cifar10.h5')
# Not necessary for demo.

# %% [markdown]
# ## Test Accuracy

# %%
# Evaluate the model on test set
score = model.evaluate(x_test, y_test, verbose=0)

# Print test accuracy
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.7966

# %% [markdown]
# ## Visualize prediction
# If the prediction matches the true label, the title will be green; otherwise it's displayed in red.

# %%
y_hat = model.predict(x_test)

# Plot a random sample of 10 test images, their predicted labels and ground truth
figure = plt.figure(figsize=(20, 8))
for i, index in enumerate(np.random.choice(x_test.shape[0], size=15, replace=False)):
    ax = figure.add_subplot(3, 5, i + 1, xticks=[], yticks=[])
    # Display each image
    ax.imshow(np.squeeze(x_test[index]))
    predict_index = np.argmax(y_hat[index])
    true_index = np.argmax(y_test[index])
    # Set the title for each image
    ax.set_title("{} ({})".format(cifar10_labels[predict_index], 
                                  cifar10_labels[true_index]),
                                  color=("green" if predict_index == true_index else "red"))
